# %%
#Import necessary modules
import pandas as pd
import geopandas as gpd
from geopandas.tools import geocode

from shapely.geometry import Point

# %%
#Filepath
fp = r"Lideres_DB.xlsx"

df = pd.read_excel(fp)
df.head()
# Out:
#                       RAW  NUM_VIC  COUNTER               NOMBRE   MUNICIP  \
# 0      1. Vicente Borrego        1        1      Vicente Borrego  Riohacha
# 1  2. Luis Carlos Tenorio        2        2  Luis Carlos Tenorio      Paez
# 2          3. Samir López        3        3   Samir López Visbal    Galapa
# 3     4. José Abdón Hoyos        4        4     José Abdón Hoyos    Satará
# 4         5. Nataly Salas        5        5         Nataly Salas  Montería
#
#        DEPART                      TO_GEOCODE      FECHA  \
# 0  La Guajira  Riohacha, La Guajira, Colombia 2016-12-01
# 1       Cáuca           Paez, Cáuca, Colombia 2016-12-02
# 2   Atlántico     Galapa, Atlántico, Colombia 2016-12-02
# 3       Cauca         Satará, Cauca, Colombia 2016-12-03
# 4     Córdoba     Montería, Córdoba, Colombia 2016-12-03
#
#                                  OCUPACION     GÉNERO  IMG_PATH  \
# 0             Líder exconcejal de Riohacha  Masculino       NaN
# ...

# %%
api = 'AIzaSyB8G6zJlaL_2LH3GTKenbo3meXi9sw9lAk'
loc = geocode(df['TO_GEOCODE'], provider='googlev3', api_key=api)
loc.head()
# Out:
#                           address                               geometry
# 0  Riohacha, La Guajira, Colombia  POINT (-72.91678379999999 11.5384151)
# 1           Paez, Cauca, Colombia               POINT (-75.9928 2.65474)
# 2     Galapa, Atlantico, Colombia   POINT (-74.88382299999999 10.898923)
# 3         Sotara, Cauca, Colombia          POINT (-76.5950555 2.2781525)
# 4     Montería, Cordoba, Colombia           POINT (-75.8785348 8.750983)

# %%
loc['LONGITUDE'] = loc['geometry'].x
loc['LATIITUDE'] = loc['geometry'].y
loc.head()
# Out:
#                           address                               geometry  \
# 0  Riohacha, La Guajira, Colombia  POINT (-72.91678379999999 11.5384151)
# 1           Paez, Cauca, Colombia               POINT (-75.9928 2.65474)
# 2     Galapa, Atlantico, Colombia   POINT (-74.88382299999999 10.898923)
# 3         Sotara, Cauca, Colombia          POINT (-76.5950555 2.2781525)
# 4     Montería, Cordoba, Colombia           POINT (-75.8785348 8.750983)
#
#    LONGITUDE  LATIITUDE
# 0 -72.916784  11.538415
# 1 -75.992800   2.654740
# 2 -74.883823  10.898923
# 3 -76.595056   2.278153
# 4 -75.878535   8.750983

# %%
df = df.join(loc)

# %%
df.to_csv('Lideres_DB_Geo.csv')
